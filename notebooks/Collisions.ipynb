# %% [markdown]
# # Finding collisions of spec pairs after PCA

# %%
from draco.learn import data_util
from draco.learn.linear import train_and_plot
from sklearn.decomposition import PCA
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data, _ = data_util.load_data()
train_and_plot(data)
# Out:
# Train score:  0.9367311072056239
# Dev score:  0.926530612244898
# LinearSVC(C=1, class_weight=None, dual=True, fit_intercept=False,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
X = data.negative - data.positive

pca = PCA(n_components=2)
X = pca.fit_transform(X)

df = pd.DataFrame(X, columns=['x0', 'x1'])

# %%
df
# Out:
#            x0        x1
# 0   -1.956128 -0.824017
# 1   -2.355852  1.120820
# 2    2.789961 -0.463775
# 3    0.731883 -1.089747
# 4    2.260277  0.291346
# 5   -1.885441  1.915867
# 6    2.376067  0.225039
# 7    0.312048 -0.412998
# 8    0.810319 -0.913535
# 9    0.312048 -0.412998
# 10  -2.395290 -1.629384
# 11  -2.253841  0.949006
# 12  -1.956128 -0.824017
# 13   0.091622 -0.245542
# 14   2.966664 -1.265798
# 15   2.427744  0.884228
# 16   0.810319 -0.913535
# 17  -0.372607  1.274275
# 18   0.355170  0.984110
# 19  -2.395290 -1.629384
# 20   0.162104 -0.093952
# 21  -1.885441  1.915867
# 22  -1.957181 -1.459302
# 23  -0.304019  2.888490
# 24  -1.719511 -0.186578
# 25  -1.885441  1.915867
# 26   0.227804 -1.984551
# 27   2.334072 -0.800621
# 28   2.281039  0.223555
# 29  -0.113464  1.761706
# ..        ...       ...
# 784 -1.551072 -1.219728
# 785 -1.949743  1.360394
# 786 -1.683809 -0.493925
# 787  2.440070  0.143823
# 788 -0.108334  1.347119
# 789  2.747893 -1.225598
# 790  2.232060 -0.628808
# 791  2.243031  0.314153
# 792  2.529341 -0.774875
# 793 -0.221075  2.058956
# 794  2.858470 -1.314683
# 795  0.601062  1.033760
# 796  0.768250 -1.675358
# 797  0.065102 -1.097934
# 798 -1.588781 -0.492441
# 799  2.900540  0.941296
# 800  2.507222  0.976281
# 801  2.927060  1.793688
# 802 -1.579777 -0.457115
# 803  0.651829 -1.424199
# 804 -2.818790  0.706065
# 805  0.107171 -0.336110
# 806  2.243031  0.314153
# 807 -1.589834 -1.127726
# 808 -2.024649 -0.604688
# 809 -0.169813  1.230855
# 810  2.884991  1.031865
# 811 -0.259837  2.150957
# 812  2.907522 -0.726157
# 813  0.369665  0.258256
#
# [814 rows x 2 columns]

# %%
df.plot.scatter(x='x0',y='x1')
